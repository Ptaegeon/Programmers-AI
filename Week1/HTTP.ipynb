# %%
import requests

# %% [markdown]
# ### https://webhook.site 에 request state 확인

# %%
payload = {'name': "Hello",
           "age": 13}
res = requests.post('https://webhook.site/3f75e95c-e314-4129-b76d-b506bd659f92', payload)
res.status_code
# Out:
# 200

# %% [markdown]
# ### Robots.txt 확인

# %%
res = requests.get('https://naver.com/robots.txt')
print(res.text)
